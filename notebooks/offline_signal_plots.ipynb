# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('../')
from utils.signal_processing import *
from utils.plots import plot_signal_epoch

print("Packages Imported")
# Out:
# Packages Imported

# %%
# so you don't have to restart the notebook for external file changes
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Session 1

# %%
# session data settings
data_filepath = '../data/emg_recordings/EMG_data_ses1.txt'
metadata_filepath = '../data/emg_recordings/EMG_metadata_ses1.txt'
channel_setup = [[1,4]]

# %%
# list of recorded behaviors
metadata = pd.read_csv(metadata_filepath, header=None).set_index(0)
metadata.index.unique()
# Out:
# Index(['Re', 'ThD', 'WrU', 'ThO', 'ClH', 'PiD', 'RiD', 'WrD', 'ClQ', 'InU',
#        'PP', 'InD', 'MiD'],
#       dtype='object', name=0)

# %%
# plot ClH
behavior = 'ClH'
plot_signal_epoch(data_filepath, metadata_filepath,behavior,channel_setup)

# %%
# Plot Re
behavior = 'Re'
plot_signal_epoch(data_filepath, metadata_filepath,behavior,channel_setup)
# Out:
# C:\Users\User\Project-TNNI-ACD\notebooks\..\utils\plots.py:81: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %% [markdown]
# ## Session 2

# %%
# session data settings
data_filepath = '../data/emg_recordings/EMG_data_ses2.txt'
metadata_filepath = '../data/emg_recordings/EMG_metadata_ses2.txt'
channel_setup = [[1,3], [6,7]]

# %%
# list of recorded behaviors
metadata = pd.read_csv(metadata_filepath, header=None).set_index(0)
metadata.index.unique()
# Out:
# Index(['Re', 'ClH', 'ThD', 'WrD', 'RiD', 'ThO', 'InU', 'ClQ', 'InD', 'PP',
#        'MiD', 'PiD', 'WrU'],
#       dtype='object', name=0)

# %%
# plot ClH
behavior = 'ClH'
plot_signal_epoch(data_filepath, metadata_filepath,behavior,channel_setup)

# %%
# Plot Re
behavior = 'Re'
plot_signal_epoch(data_filepath, metadata_filepath,behavior,channel_setup)
# Out:
# C:\Users\User\Project-TNNI-ACD\notebooks\..\utils\plots.py:81: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %% [markdown]
# ### Notes:
#
# ************
# Trial numbers refer to the order the behavior/action was performed during the session.
#
# In some cases, it's hard to see all the individual signals because lines are overlapping.
#
# Change the behavior variable to see plots of different behaviors over different trials :).
#
# If anything is sussy bakka lmk.
#
# -soysauz

# %%
# look at function docs
help(plot_signal_epoch)
# Out:
# Help on function plot_signal_epoch in module utils.plots:
#
# plot_signal_epoch(data_filepath, metadata_filepath, behavior, channel_setup, show_raw=False)
#     Plot signal epochs for a specific behavior.
#
#     Parameters:
#     -----------
#     data_filepath : str
#         Filepath of the data file.
#     metadata_filepath : str
#         Filepath of the metadata file.
#     behavior : str
#         Desired behavior for plotting signal epochs.
#     channel_setup : list
#         List of tuples representing the channel setup for plotting.
#         Each tuple contains two channel names/indices.
#     show_raw : bool, optional
#         Flag indicating whether to include raw signals in the plot.
#         Default is False.
#
#     Returns:
#     --------
#     None
#
#     Raises:
#     -------
#     FileNotFoundError
#         If either the data file or metadata file is not found.
#
#     Notes:
#     ------
#     - The function reads data and metadata as pandas DataFrames.
# ...
